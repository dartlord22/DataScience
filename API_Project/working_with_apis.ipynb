# %% [markdown]
# Setup:

# %%
import pandas as pd
import requests

# %% [markdown]
# Keys:

# %%
#API key has to be obtained from whoever you are requesting data from
API_KEY = 'AIzaSyD42nkWsMjYGKYmBLxEkKSHvhiw5LHvVNE'
CHANNEL_ID = 'UC8butISFwT-Wl7EV0hUK0BQ'

# %% [markdown]
# Now we can start building our url by adding our API KEY and CHANNEL_ID to search for freecodecamp.org

# %%
url = 'https://www.googleapis.com/youtube/v3/search?key='+API_KEY+'&channelId='+CHANNEL_ID+'&part=snippet&order=date&maxResults=100'
response = requests.get(url)
data = response.json()
print(data)
# Out:
# {'kind': 'youtube#searchListResponse', 'etag': 'YzLOxMOuB4nB4WRfKLy3GQimlUw', 'nextPageToken': 'CDIQAA', 'regionCode': 'US', 'pageInfo': {'totalResults': 183372, 'resultsPerPage': 50}, 'items': [{'kind': 'youtube#searchResult', 'etag': 'pttD5uZi6LVEdOhr2kQQDX6XkT0', 'id': {'kind': 'youtube#video', 'videoId': 'h4puc1P2VMA'}, 'snippet': {'publishedAt': '2024-05-10T14:54:28Z', 'channelId': 'UC8butISFwT-Wl7EV0hUK0BQ', 'title': 'Pro Designer Gary Simon Talks Freelance + Career Tips [Podcast #123]', 'description': "On this week's episode of the podcast, freeCodeCamp founder Quincy Larson interviews Gary Simon, a developer and designer ...", 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/h4puc1P2VMA/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/h4puc1P2VMA/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/h4puc1P2VMA/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelTitle': 'freeCodeCamp.org', 'liveBr
# ...

# %% [markdown]
# We can use the pandas function json_normalize() to give our data some readability:

# %%
pd.json_normalize(data['items']).head()
# Out:
#                    kind                         etag        id.kind  \
# 0  youtube#searchResult  pttD5uZi6LVEdOhr2kQQDX6XkT0  youtube#video
# 1  youtube#searchResult  88rwu67Jq05wjp4v6HtbT4mJRCM  youtube#video
# 2  youtube#searchResult  1yV3Wg2lYY4MYDz5CtJCGEFatoE  youtube#video
# 3  youtube#searchResult  OnjmWYJleEslmTNpJyln9Y-Z--g  youtube#video
# 4  youtube#searchResult  ygBDtKLM55CorMRz9GGBlSpAgRw  youtube#video
#
#     id.videoId   snippet.publishedAt         snippet.channelId  \
# 0  h4puc1P2VMA  2024-05-10T14:54:28Z  UC8butISFwT-Wl7EV0hUK0BQ
# 1  pHQfw1W7V8s  2024-05-09T14:21:41Z  UC8butISFwT-Wl7EV0hUK0BQ
# 2  zTjRZNkhiEU  2024-05-08T13:38:56Z  UC8butISFwT-Wl7EV0hUK0BQ
# 3  HJd1I3FdSnY  2024-05-06T13:34:38Z  UC8butISFwT-Wl7EV0hUK0BQ
# 4  fJIsqZmQVZQ  2024-05-02T14:25:51Z  UC8butISFwT-Wl7EV0hUK0BQ
#
#                                        snippet.title  \
# 0  Pro Designer Gary Simon Talks Freelance + Care...
# 1  Tezos Blockchain Developer Course – Python Web...
# ...

# %% [markdown]
# We need to create our dataframe and specify the name of our columns:

# %%
df = pd.DataFrame(columns=['video_id', 'video_title', 'upload_date', 'view_count', 'like_count', 'comment_count'])

# %% [markdown]
# Now we will begin building out our code to loop through the data.  We will begin by defining a function for a second API call to get video stats for like, view, and comment counts

# %%
def get_video_details(video_id):
           
    #collecting vew, like, dislike, comment counts
    stats_url = 'https://www.googleapis.com/youtube/v3/videos?id='+video_id+'&part=statistics&key='+API_KEY
    stats_data = requests.get(stats_url).json()
        
    view_count = stats_data['items'][0]['statistics']['viewCount']
    like_count = stats_data['items'][0]['statistics']['likeCount']
    comment_count = stats_data['items'][0]['statistics']['commentCount']
    
    return view_count, like_count, comment_count

# %% [markdown]
# Pass the function into our for loop:

# %%
for video in data['items']:
    if video['id']['kind'] == 'youtube#video':
        video_id = video['id']['videoId']
        video_title = video['snippet']['title']
        upload_date = video['snippet']['publishedAt']
        upload_date = str(upload_date).split("T")[0] #saying we only want everything on the left hand side of the T 
        
        view_count, like_count, comment_count = get_video_details(video_id)
        
        #save data in pandas df
        df = df.append({'video_id':video_id, 'video_title':video_title,
                        'upload_date':upload_date, 'view_count':view_count,
                        'like_count':like_count,'comment_count':comment_count}, ignore_index=True)
        

df.head()
# Out:
# C:\Users\dartl\AppData\Local\Temp\ipykernel_25832\1107251176.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id, 'video_title':video_title,
# C:\Users\dartl\AppData\Local\Temp\ipykernel_25832\1107251176.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id, 'video_title':video_title,
# C:\Users\dartl\AppData\Local\Temp\ipykernel_25832\1107251176.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id, 'video_title':video_title,
# ...

# %% [markdown]
# Export our data to a csv file:

# %%
df.to_csv('working_with_apis_output.csv', index=False)

# %% [markdown]
# If we want to read the csv file:

# %%
pd.read_csv('working_with_apis_output.csv')
# Out:
#        video_id                                        video_title  \
# 0   h4puc1P2VMA  Pro Designer Gary Simon Talks Freelance + Care...
# 1   pHQfw1W7V8s  Tezos Blockchain Developer Course – Python Web...
# 2   zTjRZNkhiEU              Learn Git – Full Course for Beginners
# 3   HJd1I3FdSnY                 Deep Learning Course for Beginners
# 4   fJIsqZmQVZQ  Code a Chess Game with Stockfish API – JavaScr...
# 5   5kJv254sebQ  Easily Automate Business Tasks – No-Code Autom...
# 6   tN6oJu2DqCM                    Back End Developer Roadmap 2024
# 7   mEsleV16qdo  Generative AI Full Course – Gemini Pro, OpenAI...
# 8   PSNXoAs2FtQ  Data Analyst Bootcamp for Beginners (SQL, Tabl...
# 9   ft-hs2a_zno          Calming Web Development – Colored Markers
# 10  YT8s-90oDC0                     Advanced C# Programming Course
# 11  MIL2BK02X8A  Pointers in C for Absolute Beginners – Full Co...
# 12  BpPEoZW5IiY         Learn Rust Programming - Complete Course 🦀
# ...
